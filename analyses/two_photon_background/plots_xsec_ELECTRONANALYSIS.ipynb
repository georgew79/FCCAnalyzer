# %%
import uproot
import hist
from hist import Hist
import matplotlib.pyplot as plt
import numpy as np
import mplhep as hep
import matplotlib

# %% [raw]
# First we open the ROOT file using uproot:

# %%
f_mumu = uproot.open("/home/submit/witt79/FCCAnalyzer/output_z_xsec_mumu_gagaELECTRON.root")

# %%
for key in f_mumu.keys():
    print(key) # includes a built-in "\n"
# Out:
# wz3p6_ee_gaga_mumu_ecm91p2;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_all_p_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_all_theta_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_all_phi_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_all_q_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_all_no_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_all_reso_p_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_p_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_theta_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_phi_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_q_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_no_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/leps_reso_p_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/cutFlow_cut0;1
# wz3p6_ee_gaga_mumu_ecm91p2/cutFlow_cut1;1
# wz3p6_ee_gaga_mumu_ecm91p2/cutFlow_cut2;1
# wz3p6_ee_gaga_mumu_ecm91p2/theta_plus;1
# wz3p6_ee_gaga_mumu_ecm91p2/theta_minus;1
# wz3p6_ee_gaga_mumu_ecm91p2/leading_pT;1
# wz3p6_ee_gaga_mumu_ecm91p2/subleading_pT;1
# wz3p6_ee_gaga_mumu_ecm91p2/cutFlow_cut3;1
# wz3p6_ee_gaga_mumu_ecm91p2/visibleEnergy;1
# ...

# %% [markdown]
# The histograms are saved as `process_name/histogram_name`. We will now plot the Z peak after all the cuts (stored in `zll_m_cut4`) for the main `wzp6_ee_mumu_ecm91p2` process:

# %%
z_mumu = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/zll_m_cut4'].to_hist()
z_mumu = z_mumu[::2j] # rebin with factor of 2

z_mumu_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/zll_m_cut4'].to_hist()
z_mumu_py = z_mumu_py[::2j]

z_mumu_momen_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/zll_p_cut4'].to_hist()
z_mumu_momen_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/zll_p_cut4'].to_hist()

z_mumu_momen_wh = z_mumu_momen_wh[::2j]
z_mumu_momen_py = z_mumu_momen_py[::2j]

z_mumu_pt_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/zll_pt_cut4'].to_hist()
z_mumu_pt_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/zll_pt_cut4'].to_hist()
z_mumu_pt_wh = z_mumu_pt_wh[::2j]
z_mumu_pt_py = z_mumu_pt_py[::2j]

z_mumu_eta_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/zll_eta_cut4'].to_hist()
z_mumu_eta_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/zll_eta_cut4'].to_hist()
z_mumu_eta_wh = z_mumu_eta_wh[::2j]
z_mumu_eta_py = z_mumu_eta_py[::2j]

z_mumu_ve_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/visibleEnergy'].to_hist()
z_mumu_ve_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/visibleEnergy'].to_hist()
z_mumu_ve_wh = z_mumu_ve_wh[::2j]
z_mumu_ve_py = z_mumu_ve_py[::2j]

z_mumu_tplus_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/theta_plus'].to_hist()
z_mumu_tplus_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/theta_plus'].to_hist()
z_mumu_tplus_wh = z_mumu_tplus_wh[::2j]
z_mumu_tplus_py = z_mumu_tplus_py[::2j]

z_mumu_tminus_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/theta_minus'].to_hist()
z_mumu_tminus_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/theta_minus'].to_hist()
z_mumu_tminus_wh = z_mumu_tminus_wh[::2j]
z_mumu_tminus_py = z_mumu_tminus_py[::2j]

z_mumu_leadingpT_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/leading_pT'].to_hist()
z_mumu_leadingpT_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/leading_pT'].to_hist()
z_mumu_leadingpT_wh = z_mumu_leadingpT_wh[::2j]
z_mumu_leadingpT_py = z_mumu_leadingpT_py[::2j]

z_mumu_subleadingpT_wh = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/subleading_pT'].to_hist()
z_mumu_subleadingpT_py = f_mumu['p8_ee_gaga_mumu_ecm91p2/subleading_pT'].to_hist()
z_mumu_subleadingpT_wh = z_mumu_subleadingpT_wh[::2j]
z_mumu_subleadingpT_py = z_mumu_subleadingpT_py[::2j]

# %%
font = {'family':'DejaVu Sans',
        'size'   : 22}

matplotlib.rc('font', **font)

def create_shared_ratio_hist(data1, data2, label1, label2, title, xlabel, xtop):
    # Create a figure and two subplots, sharing the same x-axis
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(15, 10), height_ratios=[2, 1])
    
    fig.subplots_adjust(hspace=0)

    hist1_y, hist1_x = data1.to_numpy()
    hist2_y, hist2_x = data2.to_numpy()
    
    # For this to work we need to 'densify' by ensuring that 
    # each axis integrates to 1. 
    # To do this normalization, we claim that
    # axis_adjusted = c * old_axis
    # where we enforce integral c * old_axis = 1
    # Therefore, we know that c = 1 / integral of old axis
    # To compute the integral of the old axis, we can sum the y col
    
    density1 = sum(hist1_y)
    density2 = sum(hist2_y)
    
    sqrt_vals1 = np.sqrt(hist1_y)
    sqrt_vals2 = np.sqrt(hist2_y)
    
    org_hist1_y = hist1_y
    org_hist2_y = hist2_y
    hist1_y = hist1_y / (density1)
    hist2_y = hist2_y / (density2)

    hist1_x = hist1_x[:-1]
    hist2_x = hist2_x[:-1]
    
    width1 = [hist1_x[i+1] - hist1_x[i] for i in range(len(hist1_x)-1)]
    width2 = [hist2_x[i+1] - hist2_x[i] for i in range(len(hist2_x)-1)] 
    
    # create top plot error bars
    # sqrt(sigma_data ^ 2 * (1 / density) ^ 2 + sigma_density ^ 2 * (- data / density)^2)
    # sigma_density = sqrt(density)
    # sigma_data = sqrt(data)
    errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
    errorbars2 = np.sqrt((org_hist2_y / (density2 ** 2)) + density2 * (np.power(org_hist2_y, 2) / (density2 ** 4)))
    
    error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

    
    # create ratio y
    hist3_y = hist1_y / (hist2_y) 
    
    # Plotting histogram on the first axis
    #ax1.bar(hist1_x[:-1], hist1_y[:-1], width=width1, align='edge', color='red', label=label1, alpha=0.7, fill=False)
    ax1.set_title(title, fontweight='bold')
    #ax1.bar(hist2_x[:-1], hist2_y[:-1], width=width2, align='edge', color='blue', label=label2, alpha=0.4, fill=False)
    ax1.step(hist1_x[:-1], hist1_y[:-1], label=label1, color='red')
    ax1.step(hist2_x[:-1], hist2_y[:-1], label=label2, color='blue')
    ax1.errorbar(hist1_x[:-1], hist1_y[:-1], yerr=errorbars1[:-1], fmt='', ls='' , label = "Whizard3 Error" , ecolor = "orange")
    ax1.errorbar(hist1_x[:-1], hist2_y[:-1], yerr=errorbars2[:-1], fmt='', ls='' , label = "Pythia8 Error" , ecolor = "green")
    
    ax1.legend()
    ax1.set_yscale('log')
    ax1.set_ylabel("Probability Density", fontweight='bold')
    
    
    #ax2.bar(hist2_x[:-1], hist3_y[:-1], width=width2, align='edge', color='black', label=f'{label1} / {label2}')
    ax2.axhline(1, linestyle='dashed', alpha=0.6)
    ax2.step(hist2_x[:-1], hist3_y[:-1], label=f'{label1} / {label2}', color='black')
    ax2.errorbar(hist2_x[:-1], hist3_y[:-1], yerr=error_ratio[:-1], fmt='', ls='' , label = "Ratio Error" , ecolor = "red")
    ax2.legend()
    ax2.set_xlim(0, xtop)
    ax2.set_xlabel(xlabel, fontweight='bold')
    ax2.set_ylabel("Ratio", fontweight='bold')
    
    plt.show()

# %%
create_shared_ratio_hist(z_mumu, z_mumu_py, 'Whizard3', 'Pythia8', 'Invariant Mass', 'Energy (GeV)', 50)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_momen_wh, z_mumu_momen_py, 'Whizard3', 'Pythia8', 'Momentum', 'Momentum (GeV)', 50)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_pt_wh, z_mumu_pt_py, 'Whizard3', 'Pythia8', 'Transverse Momentum', 'Momentum (GeV)', 10)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_eta_wh, z_mumu_eta_py, 'Whizard3', 'Pythia8', 'Pseudo-Rapidity', 'Eta (GeV)', 15)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %% [markdown]
# # Theta Analysis

# %%
z_mumu_theta = f_mumu['wz3p6_ee_gaga_mumu_ecm91p2/leps_theta_cut0'].to_hist()
z_mumu_theta = z_mumu_theta[::2j] # rebin with factor of 2

z_mumu_py_theta = f_mumu['p8_ee_gaga_mumu_ecm91p2/leps_theta_cut0'].to_hist()
z_mumu_py_theta = z_mumu_py_theta[::2j]

# %%
create_shared_ratio_hist(z_mumu_theta, z_mumu_py_theta, 'Whizard3', 'Pythia8', r'Lepton ($\theta$) Distribution', 'Angle (rad)', 3.5)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: divide by zero encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_ve_wh, z_mumu_ve_py, 'Whizard3', 'Pythia8', r'Visible Energy', 'Visible Energy (GeV)', 60)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_tplus_wh, z_mumu_tplus_py, 'Whizard3', 'Pythia8', r'($\theta$)+ Distribution', 'Theta (rad)', 3.15)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: divide by zero encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_tminus_wh, z_mumu_tminus_py, 'Whizard3', 'Pythia8', r'($\theta$)- Distribution', 'Theta (rad)', 3.15)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: divide by zero encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_leadingpT_wh, z_mumu_leadingpT_py, 'Whizard3', 'Pythia8', r'Leading pT Distributions', 'Momentum (GeV)', 25)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %%
create_shared_ratio_hist(z_mumu_subleadingpT_wh, z_mumu_subleadingpT_py, 'Whizard3', 'Pythia8', r'Subleading pT Distributions', 'Momentum (GeV)', 25)
# Out:
# /tmp/ipykernel_2159923/2160659929.py:31: RuntimeWarning: invalid value encountered in divide
#   hist1_y = hist1_y / (density1)
# /tmp/ipykernel_2159923/2160659929.py:44: RuntimeWarning: invalid value encountered in divide
#   errorbars1 = np.sqrt((org_hist1_y / (density1 ** 2)) + density1 * (np.power(org_hist1_y, 2) / (density1 ** 4)))
# /tmp/ipykernel_2159923/2160659929.py:47: RuntimeWarning: invalid value encountered in divide
#   error_ratio = np.sqrt((errorbars1/org_hist2_y)**2 + ((org_hist1_y * errorbars2)/(org_hist2_y**2))**2 )

# %% [markdown]
# # Error Fitting

# %%
from scipy.stats import weibull_min, beta
from scipy.stats import fit
# Invariant mass first
inv_mass_diffs = collect_key_diffs(z_mumu_momen_wh, z_mumu_momen_py)
_, inv_x = z_mumu_momen_wh.to_numpy()
widths = [inv_x[i+1] - inv_x[i] for i in range(len(inv_x)-1)]
inv_x = inv_x[:-1] # Remove last empty bins

res = fit(beta, inv_mass_diffs, bounds={'a':(0.000000001, 20), 'b':(0.00000000001, 20)})
print(res)
a = res.params.a
b = res.params.b

plt.plot(inv_x, beta.pdf(inv_x, a, b), 'r-', lw=5, alpha=0.6, label='beta pdf')
plt.bar(inv_x, inv_mass_diffs, width=widths, align='edge', color='black')
plt.xlim(0, 50)

## Fitting isn't going to be trivial, that's for sure...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 4
#       2 from scipy.stats import fit
#       3 # Invariant mass first
# ----> 4 inv_mass_diffs = collect_key_diffs(z_mumu_momen_wh, z_mumu_momen_py)
#       5 _, inv_x = z_mumu_momen_wh.to_numpy()
#       6 widths = [inv_x[i+1] - inv_x[i] for i in range(len(inv_x)-1)]
#
# NameError: name 'collect_key_diffs' is not defined

# %% [markdown]
# Some notes...
#
# Before 01/22/24
#
# 1. Relabel plots
# 2. Compare the 2 generators -> compare shapes of the plot
#
#     2a. Differences in the behavior? Orange much higher than blue. This is due to normalization of MC
#
#     2b. Remove normalization of Monte Carlo, can normalize by unit area --> density plot.
#
#     2c. Perform ratio plot comparison... baseline around 1. Just do it in numpy.
#
#     2d. Perhaps cut plots by 50
#
#     2e. Initial slides? Throw in slides
#
# 01/22/24

# %%
y, x = z_mumu.to_numpy()

# %% [markdown]
# To know the number of events in the histogram, we use the `.sum()` function. It returns an object containing two values: `.value` and `.variance`.

# %% [markdown]
# n_events_mumu = z_mumu.sum()
# print("Total number of events:",n_events_mumu.value)

# %% [markdown]
# # Cut Material

# %% [markdown]
# Let's get some backgrounds as well, for now we'll consider tau (`wzp6_ee_tautau_ecm91p2`) and the hadronic final states (`wzp6_ee_qq_ecm91p2`):

# %%
z_tautau = f_mumu['wzp6_ee_tautau_ecm91p2/zll_m_cut4'].to_hist()
z_tautau = z_tautau[::2j]
z_qq = f_mumu['wzp6_ee_qq_ecm91p2/zll_m_cut4'].to_hist()
z_qq = z_qq[::2j]
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 z_tautau = f_mumu['wzp6_ee_tautau_ecm91p2/zll_m_cut4'].to_hist()
#       2 z_tautau = z_tautau[::2j]
#       3 z_qq = f_mumu['wzp6_ee_qq_ecm91p2/zll_m_cut4'].to_hist()
#
# File /work/submit/submit-software/conda/envs/fcc-ee/lib/python3.10/site-packages/uproot/reading.py:2095, in ReadOnlyDirectory.__getitem__(self, where)
#    2093     else:
#    2094         last = step
# -> 2095         step = step[item]
#    2097 elif isinstance(step, uproot.behaviors.TBranch.HasBranches):
#    2098     return step["/".join(items[i:])]
#
# File /work/submit/submit-software/conda/envs/fcc-ee/lib/python3.10/site-packages/uproot/reading.py:2112, in ReadOnlyDirectory.__getitem__(self, where)
#    2109     return step
#    2111 else:
# -> 2112     return self.key(where).get()
#
# ...

# %% [markdown]
# And let's plot them stacked:

# %%
hep.histplot([z_tautau, z_qq, z_mumu], label=[r'Z($\tau\tau$)', r'Z(qq)', r'Z($\mu\mu$)'], stack=True)
plt.legend()
plt.xlim(20,100)
plt.yscale("log")

# %% [markdown]
# Now let's plot the Z peak for the different decay modes (di-muon, di-electron and hadronic):

# %%
f_ee = uproot.open("/work/submit/jaeyserm/fccee/FCCAnalyzer/output_z_xsec_ee.root")
f_qq = uproot.open("/work/submit/jaeyserm/fccee/FCCAnalyzer/output_z_xsec_qq.root")
z_ee = f_ee['wzp6_ee_ee_Mee_5_150_ecm91p2/zll_m_cut4'].to_hist()
z_ee = z_ee[::2j]
z_qq = f_qq['wzp6_ee_qq_ecm91p2/dijet_m'].to_hist()
z_qq = z_qq[::2j]
hep.histplot([z_mumu, z_ee, z_qq], label=[r'Z($\mu\mu$)', r'Z(ee)', r'Z(qq)'])
#hep.histplot([z_qq], label=[r'Z(qq)'])
plt.legend()
plt.xlim(80,100)
plt.yscale("log")
